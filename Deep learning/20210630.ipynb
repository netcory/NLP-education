# %% [markdown]
# # 딥러닝 이해(1장 ~ 5장)
#
# model.add()함수 --> 층을 쌓아 올리는 함수
#
# 층을 몇개 쌓을지는 데이터에 따라 그 때 그 때 결정
#
# 케라스의 가장 큰 장점 중 하나는 model.add() 함수로 쉽게 층을 쌓을 수 있다는 것
#
# model.add() 함수 안에는 Dense() 함수가 포함되어 있음.
#
# 딥러닝의 구조와 층별 옵션을 정하고 나면 compil() 함수를 이용해 이를 실행
#
# ## 딥러닝을 위한 기초 수학
#
# 미분을 한다는 것은 순간 변화율을 구하는 것
#
#
#
# 선형회귀
#
# 전제: 'x값이 변함에 따라 y값도 변한다'

# %% [markdown]
# 학습률과 경사하강법
#
# 학습률: 경사하강법에서 어느 정도 이동시킬지를 신중히 결정해야 하는데 이 때 이동 거리를 정하는 것
#
# 딥러닝에서 학습률의 값을 적절히 바꾸면서 최적의 학습률을 찾는 것을 최적화라고 한다.
#
# 로지스틱 회귀
