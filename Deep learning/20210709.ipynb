# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# 오늘 할 내용: RNN, 시계열 예측 분석
#
# 장고 프로젝트 시작(7/23) 전까지 2주 정도 youtube 빵형의 개발도상국 따라해보기
#
# lstm_keras_삼성전자_주식예측 실습 파일
#
# 나중에 프로젝트 주제 선정할 때 좋은 방법
# : 기존 알고리즘 공부하다보면 단점들이 보이는데 그걸 업그레이드 했다는 포트폴리오를 만들면 베스트
#
# lstm_keras_novel_writing 실습 파일
#
# prophet_corona 실습 파일
#
# word_freq_count 실습 파일
#
# cosmetic_review_sentiment_202107 실습 파일
