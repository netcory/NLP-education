# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # 모두를 위합 딥러닝 2
# # ch.1 머신러닝의 이해
#
# 텐서플로우는 로우 레벨, 그 위에서 딥러닝을 편하게 해주는 것이 케라스, 파이토치
#
# # ch2. Simple linear regression with tensorflow
#
# lab-02-1-Simple-Linear-Regression 실습 파일
#
#
# # ch.3. Linear regression and how to minimize cost
