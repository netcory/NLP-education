# %% [markdown]
# 강의자료 30. ch.5_고급 파이토치(Dataset,Ignite)
#
# 파이토치에서 제공하는 DataSet 클래스
#
# --> 데이터를 읽고 전처리 및 미니배치 위한 샘플 반환
#
# 파이토치에서 제공하는 DataLoader 클래스
#
# --> 셔플링, 미니배치 구성, Yield
#
# 05-02-Pytorch_custom_dataset_(breast_cancer-binary_classification) 실습 파일
#
# Ignite가 뭐냐? Boilerplate for DL train. PyTorch 공식 라이브러리.
#
# 데코레이터(@)는 간단히 말하면 함수에 기능을 더해준다.
#
# 05-04-pytorch_ignite 폴더 실습파일
