# %% [markdown]
# ch.16_DNN 실전 프로젝트(MNIST) 강의 자료
#
# ch16-practical_exercise 코드들 하나씩 뜯어 보기
#
# model.py
#
# trainer.py (실질적으로 model.py 를 구동시키는 파일)
#
# train.py (최상단 코드)
#
# predict.ipynb
#
# 28. ch.1_Pytorch DNN 리뷰 강의자료
#
# 29. ch.2_Representation Learning 강의자료
#
# 오늘의 메인 강의는 오토인코더
#
# 오토인코더란: 정보가 차원 축소되는 병목 구간(z)을 통과하면서 자동적으로 특징을 추출하는 방식으로 학습
#
# 딥러닝의 특성을 잘 반영한 학습 알고리즘이다.
#
# 02 representation learning 코드 분석
