# %% [markdown]
# 1. 미니 프로젝트
#
# 2. 개인 공부 알아서
#
# 3. 블로그 정리
#
# 4. 학습자료 알바
#
# 5. 스터디 자유형식
#
# ==> 2주 로테이션으로 매일 1~2시간 정도 시간 가질 수 있도록 할 방향
#
# 배운 것으로 value, 가치를 생산해야 의미가 있다.

# %% [markdown]
# ## 딥러닝 컴퍼니 가상 모의 면접
#
# 머신러닝, 딥러닝의 의미. 왜 요즘 각광받는가
#
# 자료 :
#
# 머신러닝과 딥러닝의 학습 방법의 차이에 대해 설명하시오.
#
# 자료 :
#
# 경사하강법이란 무엇인가?
#
# 자료 :
#
# 오차 역전파란 무엇인가?
#
# 자료 :
#
# 데이터 분리(학습셋, 검증셋, 테스트셋)에 대해 설명하시오.
#
# 자료 :
#
# 과적합이란 무엇이며, 딥러닝 학습 시 어떻게 과적합임을 판단하는가?
#
# ==> 데이터를 테스트셋, 검증셋으로 나누고 검증셋으로 검증시 loss가 증가하는 순간이 온다. 이 때 과적합이 발생하기 시작한 것이다.
#
# 자료 :

# %% [markdown]
# parameter와 argument의 차이.
#
# 매개변수 parameter는 함수 정의시, 전달인자 argument는 실제로 우리가 입력하는 값
#
# hyper-parameter 와 parameter의 차이도.

# %% [markdown]
# # ch.10 딥러닝 모델 설계하기
#
# 01_My_First_Deeplearning 실습 파일

# %% [markdown]
# 데이터의 양보다 훨씬 중요한 것은, '필요한' 데이터가 얼마나 있는가다.
#
# 무조건 빅 데이터가 중요한 게 아님.
#
# 머신러닝 프로젝트의 성공과 실패는 얼마나 좋은 데이터를 가지고 시작하느냐에 영향을 받는다.
#
# 좋은 데이터란 내가 알아내고자 하는 정보를 잘 담고 있는 데이터.
#
# 한쪽으로 치우치지 않고, 불필요한 정보를 가지고 있지 않고, 왜곡되지 않은 데이터.

# %% [markdown]
# # ch.11 데이터 다루기
#
# 02_Pima_Indian 실습 파일

# %% [markdown]
# # ch.12  다중 분류문제 해결
#
# 03_Iris_Multi_Classification 실습 파일
#
# batch_size 는 어떻게 설정할 것인가?
#
# 뒤에 나오지만 보통 2의 제곱수 (2, 4, 8, 16, 32...컴퓨터가 이진법이라서 효율이 좋다는데)

# %% [markdown]
# # ch.13 과적합 피하기
#
# 04_Sonar 실습 파일
#
# 학습을 진행해도 검증셋 결과가 더 이상 좋아지지 않는 지점에서 학습을 멈춰야 함.
#
# (자료에 따라서 검증셋이 아니라 테스트 셋이라는 표현도 하는데 정확히 말하면
# 테스트 데이터는 학습에 관여하지 않는 것이 맞고 학습 중에 과적합 검증을 위해 사용되는 데이터를
# 검증셋이라고 부르는 것이 맞음)
#
# 05_Sonar_Train_Test 실습 파일
#
#
# 06-Sonar-Save_Model 실습 파일
#
# (파일 생성해서) 모델 저장과 재사용
#
# 학습이 끝난 후 테스트 해본 결과가 만족스러울 때 이를 모델로 저장하여 새로운 데이터에 사용 가능
#
# model.save 함수
#
#
#
# k겹 교차 검증
#
# setosa, versicolor, virginica 순서로 쭉 나열된 데이터가 있다면
#
# 얘네를 섞어서 검증해야 효과가 있다 --> StratifiedKFold() 함수
#
# 07_Sonar-K-fold 실습 파일
#
# But, 딥러닝에서는 교차 검증 별로 쓸 일이 없다. == ch.14

# %% [markdown]
# # ch.14 베스트 모델 만들기
#
# 10_Wine_Overfit_Graph 실습 파일. (10번 파일에 8, 9 다 들어가 있어서 건너 뜀)
#
# 얼리스타핑 설정

# %% [markdown]
# # ch.15 선형회귀 적용하기
#
# 13_Boston 실습 파일
