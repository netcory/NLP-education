# %% [markdown]
# # 파이토치 계속해서
#
# ## 15.ch.4_PyTorch&Tensor_tutorial
#
# 04-06-tensor_shape_manipulations 실습 파일
#
# 04-07-tensor_indexing_slicing_and_concat 실습 파일
#
# list 인덱싱 슬라이싱 했듯이 2차원, 3차원 텐서도 같은 방식으로 접근
#
# 04-08-tensor_useful_methods 실습 파일
#
# ## 16.ch.5_신경망의 기본 구성요소
#
# 05-02-matrix_multiplication 실습 파일
#
# ******강의자료 ch.5.4 가 가장 중요******
#
# 파이썬 코딩도장 강의자료 클래스, 상속 복습
#
# *******05-04-실습 - Linear Layer(with nn.Module) 실습 파일******* 핵 중요!

# %%
import torch

# %%
torch.__version__
# Out:
# '1.9.0'

# %%
import torch

# %%
torch.__version__
# Out:
# '1.9.0'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3070 Laptop GPU'

# %%
torch.cuda.device_count()
# Out:
# 1
