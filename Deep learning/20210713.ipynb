# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # 머신러닝, 딥러닝 여태까지 한 것 정리
#
# ## 머신러닝
#
# <프레임워크> - 사이킷런
#
# <알고리즘> - 분류, 회귀, PCA, 군집화, 추천시스템, 텍스트분석
#
# <학습 방법> - 로지스틱 회귀, 랜덤포레스트, XGBoost, LightGBM, 선형회귀, 규제(L1/L2) 회귀
#
# <평가표> - 정확도, 정밀도, 재현율, F1스코어, ROC-AUC, MSE 계열
#
#
#
# ## 딥러닝
#
# <프레임워크> - 케라스, 텐서플로우, 파이토치
#
# <알고리즘> - DNN, RNN, LSTM, CNN
#
# <학습방법> - *경사하강법(optimizer)(딥러닝에서 가장 중요하다고 봐도 무방), Gradient Descent, 오차역전파(back-propagation), 학습률
#
# <평가지표> - cross-entropy(category/binary), MSE 계열
#
# <(overfit을 피하기) 학습을 잘하는 법> - SGD(미니배치), 드랍아웃, 맥스풀링, early-stopping, validation check, w파라미터 초기화(Xavier, He)
#
#
#
# 어차피 한 번에 다 이해될 수 없다. 키워드들 갖고 흐름을 이해하자.
#
# 앞으로는 구체적으로 딥러닝 코딩을 해볼텐데 class 개념이 중요

# %% [markdown]
# # 클래스 개념 다시 정리
#
# - 클래스: 객체를 만들기 위한 설계도
#
# - 객체(인스턴스): 설계도로부터 만들어낸 제품
#
# 01.클래스 개념 실습 파일
#
# 02.클래스 만들기 실습 파일
#
# 03.생성자 실습 파일
#
# 04.상속 실습 파일

# %% [markdown]
# # 파이토치
#
# 강의자료 15. ch.4_PyTorch&Tensor_tutorial
#
# pytorch.org 에서 알려주는 명령어 따라 pytorch 설치
#
# 04-02-hello_pytorch 실습 파일
#
# 04-04-tensor-dtype~
#
# 04-05-tensor-operation~
#
# 04-06-tensor-shape~ 실습 파일
