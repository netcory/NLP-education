# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # ch.16 CNN
#
# 이미지 인식의 꽃, CNN
#
# 실습과제: MNIST 손글씨 인식
#
# CNN이 무엇인가?
#
# 네트워크를 세팅한다는 것에 대해 다시 생각.
#
# 원래 입력이라는 feature가 있다. (아이리스 데이터 같은 경우 4개, MNIST 숫자 이미지는 784개)
#
# CNN은 다시 한 번 특징을 추출하기 위해 마스크(=필터, 윈도, 커널)를 도입하는 기법
#
# 16_MNIST_Deep 실습 파일
#
# # ch.17 자연어 처리
#
# 17_NLP_lecturer_source 실습 파일
