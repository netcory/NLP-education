# %% [markdown]
# # 이번주 (7/19 ~ 7/23) 배우는 게 이 과정 전체의 허리
#
# 08-03-linear_regression_boston_housing 실습 파일
#
# optimizer adam을 사용하는 이유: learning_rate를 신경 안써도 되게 해준다.
#
# 강의자료 20. ch.9_로지스틱 회귀
#
# 선형회귀 모델 마지막에 sigmoid 함수를 통과시키면 로지스틱 회귀
#
# 로지스틱 회귀는 이름은 회귀이지만 사실은 이진 분류 문제다.
#
# 09-02-activation_functions-sigmoid,tanh 실습 파일
#
# 09-06-Logistic_regression(breast cancer) 실습 파일
#
# 강의자료 21. ch.10_DNN_Regression(Back-propagation)
#
# 10-06-dnn_regression 실습 파일
#
# 강의 자료 22. ch.11_SGD DNN Regression
#
# 11-04-sgd_dnn_regression 실습 파일
